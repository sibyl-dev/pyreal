# %%
import pandas as pd
import numpy as np
import real

import importlib
importlib.reload(real.applications.titanic)
# Out:
# <module 'real.applications.titanic' from 'C:\\Users\\Ola\\Documents\\Research\\Implementations\\EvaluatingXAI\\sibyl\\real\\applications\\titanic.py'>

# %%
x_orig, y = real.applications.titanic.load_titanic_data()
model = real.applications.titanic.load_titanic_model()
transformers = real.applications.titanic.load_titanic_transformers()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-41f51af627ce> in <module>()
#       1 x_orig, y = real.applications.titanic.load_titanic_data()
#       2 model = real.applications.titanic.load_titanic_model()
# ----> 3 transformers = real.applications.titanic.load_titanic_transformers()
#
# ~\Documents\Research\Implementations\EvaluatingXAI\sibyl\real\applications\titanic.py in load_titanic_transformers()
#      20
#      21 def load_titanic_transformers():
# ---> 22     return pickle.load(open(os.path.join(DATA_DIR, "transformers.pkl"), "rb"))
#
# AttributeError: Can't get attribute 'ColumnDropTransformer' on <module '__main__'>
