# %%
from pyreal import RealApp
import pyreal.sample_applications.titanic as titanic

x_train_orig, y = titanic.load_titanic_data()
model = titanic.load_titanic_model()
transformers = titanic.load_titanic_transformers()
feature_descriptions = titanic.load_feature_descriptions()

realApp = RealApp(model, x_train_orig, y_orig=y, transformers=transformers, feature_descriptions=feature_descriptions)

# %%
explanation = realApp.produce_local_feature_contributions(x_train_orig.iloc[0:100])
# Out:
# The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
from pyreal.visualize import plot_top_contributors

print("Prediction: ", realApp.predict(x_train_orig.iloc[1]))
plot_top_contributors(explanation[1])
# Out:
# Prediction:  [1]

# %%
from pyreal.visualize import swarm_plot

swarm_plot(explanation, type="strip")
# Out:
# The palette list has more values (46) than needed (45), which may not be intended.
# The palette list has more values (4) than needed (3), which may not be intended.
